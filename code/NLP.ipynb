# %%
import pandas as pd
import numpy as np

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-c151c81f-0926-40be-ad4c-e7daa5e9f830" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c151c81f-0926-40be-ad4c-e7daa5e9f830">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
pip install wordcloud

# %%
d = pd.read_csv("updated.csv")
x = d['Name of Project']
d
# Out:
#       Unnamed: 0.1  Unnamed: 0                                   Fund  \
# 0                0           0               Green Climate Fund (GCF)
# 1                1           1      Global Environment Facility (GEF)
# 2                2           2      Global Environment Facility (GEF)
# 3                3           3  Least Developed Countries Fund (LDCF)
# 4                4           4  Least Developed Countries Fund (LDCF)
# ...            ...         ...                                    ...
# 3235          3235        3235               Green Climate Fund (GCF)
# 3236          3236        3236     Special Climate Change Fund (SCCF)
# 3237          3237        3237     Special Climate Change Fund (SCCF)
# 3238          3238        3238      Global Environment Facility (GEF)
# 3239          3239        3239      Global Environment Facility (GEF)
#
#          Fund Type      Country   World Bank Region Income Classification  \
# ...

# %%
import numpy as np
from PIL import Image
from wordcloud import WordCloud
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
import re
for i in d['Name of Project']:
 x = re.sub("[0-9]","",i)
 print(x)
#Out: 'abdE'
# Out:
# (fp) strengthening climate resilience of subsistence farmers and agricultural plantation communities residing in the vulnerable river basins, watershed areas and downstream of the knuckles mountain range catchment of sri lanka
# accelerating adoption of super-efficient technologies for sustainable thermal comfort in buildings in india
# achieving reduction in ghg emissions through advanced energy efficiency technology in electric motors
# adapting afghan communities to climate-induced disaster risks
# addressing the risk of climate-induced disasters through enhanced national and local capacity for effective actions
# strengthened approach for the integration of sustainable environmental management into the ands/prsp
#
# appropriate mitigation actions in the energy generation and end-use sectors in sri lanka
# astud: greater dhaka sustainable urban transport corridor project
# bangladesh: first biennial update report (bur) to the unfccc
# ...

# %%
d.columns
# Out:
# Index(['Unnamed: 0.1', 'Unnamed: 0', 'Fund', 'Fund Type', 'Country',
#        'World Bank Region', 'Income Classification', 'Name of Project',
#        'Theme/Objective', 'Sector (OECD)', 'Key words', 'Summary ',
#        'Implementing Agency', 'Recipient Institution',
#        'Recipient Institution type', 'Approved year', 'End year',
#        'Completed Project', 'Project Duration',
#        'Amount of Funding Approved (USD millions)', 'Least Developed Country',
#        'Small Island Developing Nation', 'Fragile or Conflict Affected State',
#        'categories'],
#       dtype='object')

# %%
d['Key words']
# Out:
# 0                           smallholders, resilience
# 1                                                  0
# 2                                                  0
# 3                                                  0
# 4                                                  0
#                             ...
# 3235             adaptive capacity, climate forecast
# 3236                                               0
# 3237                                        droughts
# 3238                          mini-grids; renewables
# 3239    monitoring, reporting and verification (mrv)
# Name: Key words, Length: 3240, dtype: object

# %%
import re
for i in d['Key words']:
 r = re.sub("[0-9]","",i)
 print(r)
# Out:
# smallholders, resilience
#
#
#
#
#
#
#
# reporting
#
# capacity building
# adaptation, communication, knowledge
#
# readiness support
#
#
# reporting
# eba
# reporting
# ghg emissions, electric mobility
#
#
# rural, sustainable energy access
#
#
# coastal protection, capacity building
# land
# napa
#
#
#
#
# smallholders, water provision
# innovative financing mechanisms
#
# agro-ecosystems, early warning systems, capacity building
# agriculture, resilience, livestock production, crops
# readiness support
# coastal, vulnerable, flooding
# food security, ecosystems
#
#
# natural ecosystems
# biological diversity
#
#
# buildings
#
#
# reporting
#
#
#
#
# waste management, floot management
#
#
#
# agriculture, land degradation
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# readiness support
# ...

# %%
wc = WordCloud(background_color='black', colormap = 'BuGn_r',width = 800, height = 500).generate(x)
plt.imshow(wc)
plt.axis("off")
# Out:
# (-0.5, 799.5, 499.5, -0.5)

# %%
wc = WordCloud(background_color='black', colormap = 'BuGn_r',
     stopwords = ['meta'], width = 800, height = 500).generate(x)
plt.axis("off")
plt.imshow(wc)

# %%
from os import path, getcwd
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
from wordcloud import WordCloud, ImageColorGenerator

# %%
 np.array(Image.open('./meta_logo.png'))

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
df = pd.read_excel('/content/drive/My Drive/Datathon/Data/Cleaned_Projects.xlsx')

# %%
len(df)

# %%
df = pd.read_csv("Cleaned_Projects.csv")
df.head()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-17-a553d91804fb> in <cell line: 1>()
# ----> 1 df = pd.read_csv("Cleaned_Projects.csv")
#       2 df.head()
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
dfx = df['Name of Project']
dfx
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-18-eeba79a7e202> in <cell line: 1>()
# ----> 1 dfx = df['Name of Project']
#       2 dfx
#
# NameError: name 'df' is not defined

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-cd7d6c6a-7dfb-46aa-9680-74b313680c7c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-cd7d6c6a-7dfb-46aa-9680-74b313680c7c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df2 = pd.read_excel("Pre Train Labels.xlsx")
df2
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-6-30911dc92876> in <cell line: 1>()
# ----> 1 df2 = pd.read_excel("Pre Train Labels.xlsx")
#       2 df2
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     209                 else:
#     210                     kwargs[new_arg_name] = new_arg_value
# --> 211             return func(*args, **kwargs)
#     212
#     213         return cast(F, wrapper)
#
# /usr/local/lib/python3.10/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# ...

# %%
df2 = pd.read_csv("Pre Train Labels - Sheet1.csv")
df2
# Out:
#                                              Label  \
# 0                                       Governance
# 1                                   User Interface
# 2                               Observation System
# 3    Provision and application of climate services
# 4                Research modelling and prediction
# ..                                             ...
# 129                                 User Interface
# 130                             Observation System
# 131                             Observation System
# 132                             Observation System
# 133                             Observation System
#
#                                                Meaning
# 0    National Governance mechanisms to ensure coord...
# 1    Mechanisms, tools, and systems that allow clim...
# 2    Comprising observing networks, data, data mana...
# 3    Decision support products and services, provis...
# 4    To advance the science needed for improved cli...
# ...

# %%
(df2['Label'].unique())

# %%
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords

# %%
import logging
import pandas as pd
import numpy as np
from numpy import random
import gensim
import nltk
from sklearn.model_selection import train_test_split
from sklearn.feature_extraction.text import CountVectorizer, TfidfVectorizer
from sklearn.metrics import accuracy_score, confusion_matrix
import matplotlib.pyplot as plt
from nltk.corpus import stopwords
import re
from bs4 import BeautifulSoup
# %matplotlib inline

from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import Pipeline
from sklearn.feature_extraction.text import TfidfTransformer

# %%
X = df2['Meaning']
y = df2['Label']
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state = 42)

# %%
x = ['Governance', 'User Interface', 'Observation System',
       'Provision and application of climate services',
       'Research modelling and prediction', 'Capacity development',
       'Monitoring and Evaluation of climate services',
       'Disaster risk knowledge and management',
       'Detection, Observation, Monitoring, Analysis & Forecasting of Hazards ',
       'Warning Dissemination and Communication ',
       'Disaster Preparedness and Response']
len(x)
# Out:
# 11

# %%
from sklearn.linear_model import SGDClassifier
from sklearn.metrics import classification_report

sgd = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', SGDClassifier(loss='hinge', penalty='l2',alpha=1e-3, random_state=42, max_iter=5, tol=None)),
               ])
sgd.fit(X_train, y_train)

y_pred = sgd.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred, y_test))
print(classification_report(y_test, y_pred,target_names=x))
# Out:
# accuracy 0.5365853658536586
#                                                                         precision    recall  f1-score   support
#
#                                                             Governance       1.00      1.00      1.00         2
#                                                         User Interface       0.43      1.00      0.60         3
#                                                     Observation System       0.75      0.75      0.75         4
#                          Provision and application of climate services       0.80      0.80      0.80         5
#                                      Research modelling and prediction       0.36      1.00      0.53         4
#                                                   Capacity development       1.00      0.50      0.67         2
#                          Monitoring and Evaluation of climate services       1.00      0.33      0.50         3
# ...

# %%
from sklearn.metrics import hamming_loss
print('Hamming Loss: ', round(hamming_loss(y_test, y_pred),2))

# %%
d['categories'] = (sgd.predict(x))

# %%
d[(d['categories'] == 'Research modelling and prediction')]
# Out:
# Empty DataFrame
# Columns: [Unnamed: 0.1, Unnamed: 0, Fund, Fund Type, Country, World Bank Region, Income Classification, Name of Project, Theme/Objective, Sector (OECD), Key words, Summary , Implementing Agency, Recipient Institution, Recipient Institution type, Approved year, End year, Completed Project, Project Duration, Amount of Funding Approved (USD millions), Least Developed Country, Small Island Developing Nation, Fragile or Conflict Affected State, categories]
# Index: []
#
# [0 rows x 24 columns]

# %%
# Accessing Google Drive

from google.colab import drive
drive.mount('/content/drive')

# %%
df.to_csv('/content/drive/My Drive/Datathon/Data/mydata.csv')

# %%
len(df)

# %%
from sklearn.linear_model import LogisticRegression

logreg = Pipeline([('vect', CountVectorizer()),
                ('tfidf', TfidfTransformer()),
                ('clf', LogisticRegression(n_jobs=1, C=1e5)),
               ])
logreg.fit(X_train, y_train)


y_pred2 = logreg.predict(X_test)

print('accuracy %s' % accuracy_score(y_pred2, y_test))
print(classification_report(y_test, y_pred2,target_names=x))

# %%
from sklearn.metrics import hamming_loss
print('Hamming Loss: ', round(hamming_loss(y_test, y_pred2),2))

# %%
logreg.predict(dfx)

# %%
from sklearn.metrics import hamming_loss
print('Hamming Loss: ', round(hamming_loss(y_test, prediction),2))
